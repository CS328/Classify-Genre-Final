# %%
import os
import sys
import math

import matplotlib
import matplotlib.pyplot as plt
import pylab as pl
import numpy as np
import pandas as pd

from scipy.io.wavfile import read
from scipy.fft import fft, ifft
import pickle


matplotlib.style.use('ggplot')
# %matplotlib notebook

# %%
data = read("speaker-data-enter_sandman-2.wav")
audio = data[1]

window = audio[200000: 300000]

plt.figure(figsize=(10,5))
plt.plot(window)
plt.ylabel("Amplitude")
plt.xlabel("Time")
plt.title("Metal: Enter Sandman")
plt.show()

plt.figure(figsize=(10,5))
windowfft = fft(window)
plt.plot(abs(windowfft[: , 1]))
plt.title("Metal: Enter Sandman FFT")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
data = read("speaker-data-Waiting_For_Love-0.wav")
audio = data[1]

window = audio[200000: 300000]

plt.figure(figsize=(10,5))
plt.plot(window)
plt.ylabel("Amplitude")
plt.xlabel("Time")
plt.title("EDM: Waiting For Love -Avicii")
plt.show()

plt.figure(figsize=(10,5))
windowfft = fft(window)
plt.plot(abs(windowfft[: , 1]))
plt.title("EDM: Waiting For Love FFT")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">
# <img src="data:image/png;base64,..." width="999.9999783255842">
